# %% [markdown]
# ### Class Relationships
#
# - Aggregation
# - Inheritance

# %% [markdown]
# ### Aggregation(Has-A relationship)
#
# - One class owns the other class
# - In aggregation you can't change the private variables

# %%
# example
class Customer:

    #constructor
  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address._Address__city,self.address.pin,self.address.state)   #self.address.get__city

    # Adding method
  def edit_profile(self,new_name,new_city,new_pin,new_state):
    self.name = new_name
    self.address.edit_address(new_city,new_pin,new_state)

    # Another class for address because it has other attributes
class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state

  def get_city(self):
    return self.__city

  def edit_address(self,new_city,new_pin,new_state):
    self.__city = new_city
    self.pin = new_pin
    self.state = new_state

add1 = Address('gurgaon',122011,'haryana')
cust = Customer('Ravikant','male',add1)

cust.print_address()

cust.edit_profile('Shagun','Moradabad',244002,'Uttar-Pradesh')
cust.print_address()
# method example
# what about private attribute
# Out:
# gurgaon 122011 haryana
# Moradabad 244002 Uttar-Pradesh

# %% [markdown]
# ##### Aggregation class diagram
#
# ![employee.jpg](attachment:employee.jpg)
# - '-' means Private
# - '+' means public

# %% [markdown]
# ### Inheritance
#
# - What is inheritance
# - Example
# - What gets inherited?
# ![Capture.PNG](attachment:Capture.PNG)

# %%
# Inheritance and it's benefits
# Optimize your code by Code reuseability

# %%
# Example

# parent
class User:

  def __init__(self):
    self.name = 'Ravikant'    #non private attribute
    self.gender = 'male'

  def login(self):
    print('login')

# child
class Student(User):    # (User) -< this show inheritance and this class becomes a child class

#   def __init__(self):       # method overriding
#     self.rollno = 100

  def enroll(self):
    print('enroll into the course')

u = User()
s = Student()

print(s.name)
s.login()
s.enroll()
# Out:
# Ravikant
# login
# enroll into the course

# %% [markdown]
# ##### What gets inherited?
#
# - Constructor
# - Non Private Attributes
# - Non Private Methods

# %% [markdown]
# #### Class Diagram
# ![images.png](attachment:images.png)

# %% [markdown]
# #### Basic Notations
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# #### Various symbols
# ![download.png](attachment:download.png)

# %%
# constructor example

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):   # If child has no constructor then it can use parent constructor
    pass

s=SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# constructor example 2

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, os, ram):
        self.os = os
        self.ram = ram
        print ("Inside SmartPhone constructor")

s=SmartPhone("Android", 2)
s.brand      # Error is occur because if child class has a constructor then parent class will not being called or initialised
# Out:
# Inside SmartPhone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 17
#      14         print ("Inside SmartPhone constructor")
#      16 s=SmartPhone("Android", 2)
# ---> 17 s.brand
#
# AttributeError: 'SmartPhone' object has no attribute 'brand'

# %%
# child can't access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
s.show()   
s.check()
# Out:
# Inside phone constructor
# 20000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 20
#      18 s=SmartPhone(20000, "Apple", 13)
#      19 s.show()
# ---> 20 s.check()
#
# Cell In[14], line 16, in SmartPhone.check(self)
#      15 def check(self):
# ---> 16     print(self.__price)
#
# AttributeError: 'SmartPhone' object has no attribute '_SmartPhone__price'

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def show(self):
        print("This is in child class")
        
son=Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,val,num):
        self.__val=val

    def get_val(self):
        return self.__val
        
son=Child(100,10)
print("Parent: Num:",son.get_num())
print("Child: Val:",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 18
#      15         return self.__val
#      17 son=Child(100,10)
# ---> 18 print("Parent: Num:",son.get_num())
#      19 print("Child: Val:",son.get_val())
#
# Cell In[2], line 7, in Parent.get_num(self)
#       6 def get_num(self):
# ----> 7     return self.__num
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
class A:
    def __init__(self):
        self.var1=100

    def display1(self,var1):
        print("class A :", self.var1)
class B(A):
  
    def display2(self,var1):
        print("class B :", self.var1)

obj=B()
obj.display1(200)
# Out:
# class A : 100

# %%
# Method Overriding
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")  # if same method written in parent and child class then child class method will be executed

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone

# %% [markdown]
# ### Super Keyword

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# using super outside the class
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# super access parent ka data
# using super outside the class
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        print(super().brand)

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 21
#      17         print(super().brand)
#      19 s=SmartPhone(20000, "Apple", 13)
# ---> 21 s.buy()
#
# Cell In[7], line 17, in SmartPhone.buy(self)
#      15 print ("Buying a smartphone")
#      16 # syntax to call parent ka buy method
# ---> 17 print(super().brand)
#
# AttributeError: 'super' object has no attribute 'brand'

# %%
# super -> constuctor
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, price, brand, camera, os, ram):
        print('Inside smartphone constructor')
        super().__init__(price, brand, camera)
        self.os = os
        self.ram = ram
        print ("Inside smartphone constructor")

s=SmartPhone(20000, "Samsung", 12, "Android", 2)

print(s.os)
print(s.brand)
#s.super().buy()    error throw
# Out:
# Inside smartphone constructor
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung

# %% [markdown]
# ##### Inheritance in summary
#
# - A class can inherit from another class.
#
# - Inheritance improves code reuse
#
# - Constructor, attributes, methods get inherited to the child class
#
# - The parent has no access to the child class
#
# - Private properties of parent are not accessible directly in child class
#
# - Child class can override the attributes or methods. This is called method overriding
#
# - super() is an inbuilt function which is used to invoke the parent class methods and constructor
